# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 0
set_count = 0
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        temp = city_weather["weather"]
        weather_description = temp[0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 of Set 0 | chokurdakh
# Processing Record 1 of Set 0 | georgetown
# Processing Record 2 of Set 0 | kaitangata
# Processing Record 3 of Set 0 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 0 | tasiilaq
# Processing Record 5 of Set 0 | kodiak
# Processing Record 6 of Set 0 | hermanus
# Processing Record 7 of Set 0 | puerto ayora
# Processing Record 8 of Set 0 | konstantinovka
# Processing Record 9 of Set 0 | rikitea
# Processing Record 10 of Set 0 | port alfred
# Processing Record 11 of Set 0 | roald
# Processing Record 12 of Set 0 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 0 | bredasdorp
# Processing Record 14 of Set 0 | lompoc
# Processing Record 15 of Set 0 | punta arenas
# Processing Record 16 of Set 0 | ushuaia
# Processing Record 17 of Set 0 | saint-philippe
# Processing Record 18 of Set 0 | hithadhoo
# Processing Record 19 of Set 0 | saint-francois
# Processing Record 20 of Set 0 | lichinga
# Processing Record 21 of Set 0 | ozinki
# Processing Record 22 of Set 0 | sambava
# Processing Record 23 of Set 0 | etchoropo
# Processing Record 24 of Set 0 | cherskiy
# Processing Record 25 of Set 0 | quelimane
# Processing Record 26 of Set 0 | kamenka
# Processing Record 27 of Set 0 | trairi
# Processing Record 28 of Set 0 | viedma
# Processing Record 29 of Set 0 | upernavik
# Processing Record 30 of Set 0 | saldanha
# Processing Record 31 of Set 0 | cape town
# Processing Record 32 of Set 0 | guerrero negro
# Processing Record 33 of Set 0 | domoni
# Processing Record 34 of Set 0 | okhotsk
# Processing Record 35 of Set 0 | mana
# Processing Record 36 of Set 0 | barrow
# Processing Record 37 of Set 0 | albany
# Processing Record 38 of Set 0 | bilibino
# Processing Record 39 of Set 0 | antofagasta
# Processing Record 40 of Set 0 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 0 | yellowknife
# Processing Record 42 of Set 0 | acapulco
# Processing Record 43 of Set 0 | west wendover
# Processing Record 44 of Set 0 | new norfolk
# Processing Record 45 of Set 0 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 0 | tanout
# Processing Record 47 of Set 0 | kapaa
# Processing Record 48 of Set 0 | esperance
# Processing Record 49 of Set 0 | sorland
# Processing Record 1 of Set 1 | hurghada
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 1 | lebu
# Processing Record 6 of Set 1 | boguchany
# Processing Record 7 of Set 1 | castro
# Processing Record 8 of Set 1 | bambous virieux
# Processing Record 9 of Set 1 | yian
# City not found. Skipping...
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | cayenne
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | avarua
# Processing Record 15 of Set 1 | solsvik
# City not found. Skipping...
# Processing Record 16 of Set 1 | karratha
# Processing Record 17 of Set 1 | sakakah
# Processing Record 18 of Set 1 | fiumicino
# Processing Record 19 of Set 1 | madimba
# Processing Record 20 of Set 1 | tura
# Processing Record 21 of Set 1 | dingle
# Processing Record 22 of Set 1 | saskylakh
# Processing Record 23 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | miri
# Processing Record 26 of Set 1 | camacha
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | brae
# Processing Record 29 of Set 1 | mayumba
# Processing Record 30 of Set 1 | iralaya
# Processing Record 31 of Set 1 | yar-sale
# Processing Record 32 of Set 1 | sao joao da barra
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | mezen
# Processing Record 36 of Set 1 | east london
# Processing Record 37 of Set 1 | port macquarie
# Processing Record 38 of Set 1 | beisfjord
# Processing Record 39 of Set 1 | kruisfontein
# Processing Record 40 of Set 1 | codrington
# Processing Record 41 of Set 1 | guarapari
# Processing Record 42 of Set 1 | port elizabeth
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | karauzyak
# City not found. Skipping...
# Processing Record 45 of Set 1 | bhubaneswar
# Processing Record 46 of Set 1 | iztapa
# Processing Record 47 of Set 1 | souillac
# Processing Record 48 of Set 1 | fare
# Processing Record 49 of Set 1 | aklavik
# Processing Record 50 of Set 1 | jos
# Processing Record 1 of Set 2 | high level
# Processing Record 2 of Set 2 | norman wells
# Processing Record 3 of Set 2 | harper
# Processing Record 4 of Set 2 | salalah
# Processing Record 5 of Set 2 | zachary
# Processing Record 6 of Set 2 | barcelos
# Processing Record 7 of Set 2 | ciro marina
# Processing Record 8 of Set 2 | uyemskiy
# Processing Record 9 of Set 2 | pingxiang
# Processing Record 10 of Set 2 | wanlaweyn
# Processing Record 11 of Set 2 | alyangula
# Processing Record 12 of Set 2 | at-bashi
# Processing Record 13 of Set 2 | moron
# Processing Record 14 of Set 2 | cidreira
# Processing Record 15 of Set 2 | komsomolskiy
# Processing Record 16 of Set 2 | broome
# Processing Record 17 of Set 2 | provideniya
# Processing Record 18 of Set 2 | northam
# Processing Record 19 of Set 2 | chuy
# Processing Record 20 of Set 2 | college
# Processing Record 21 of Set 2 | cabo san lucas
# Processing Record 22 of Set 2 | prudyanka
# Processing Record 23 of Set 2 | hambantota
# Processing Record 24 of Set 2 | umm lajj
# Processing Record 25 of Set 2 | kahului
# Processing Record 26 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 2 | katsiveli
# City not found. Skipping...
# Processing Record 28 of Set 2 | forset
# City not found. Skipping...
# Processing Record 29 of Set 2 | klyuchi
# Processing Record 30 of Set 2 | mahebourg
# Processing Record 31 of Set 2 | henties bay
# Processing Record 32 of Set 2 | constitucion
# Processing Record 33 of Set 2 | bethel
# Processing Record 34 of Set 2 | frontera
# Processing Record 35 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 2 | palmer
# Processing Record 38 of Set 2 | atmakur
# Processing Record 39 of Set 2 | namatanai
# Processing Record 40 of Set 2 | mgandu
# Processing Record 41 of Set 2 | itarema
# Processing Record 42 of Set 2 | dikson
# Processing Record 43 of Set 2 | foshan
# Processing Record 44 of Set 2 | kurilsk
# Processing Record 45 of Set 2 | norden
# Processing Record 46 of Set 2 | port hardy
# Processing Record 47 of Set 2 | rocha
# Processing Record 48 of Set 2 | vesoul
# Processing Record 49 of Set 2 | kholodnyy
# Processing Record 50 of Set 2 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 1 of Set 3 | mount gambier
# Processing Record 2 of Set 3 | kaeo
# Processing Record 3 of Set 3 | formosa
# Processing Record 4 of Set 3 | bluff
# Processing Record 5 of Set 3 | berlevag
# Processing Record 6 of Set 3 | grand gaube
# Processing Record 7 of Set 3 | mocorito
# Processing Record 8 of Set 3 | faanui
# Processing Record 9 of Set 3 | aykhal
# Processing Record 10 of Set 3 | bulgan
# Processing Record 11 of Set 3 | omsukchan
# Processing Record 12 of Set 3 | santa cruz de tenerife
# Processing Record 13 of Set 3 | nardaran
# Processing Record 14 of Set 3 | hofn
# Processing Record 15 of Set 3 | bollnas
# Processing Record 16 of Set 3 | hami
# Processing Record 17 of Set 3 | udachnyy
# Processing Record 18 of Set 3 | ponta do sol
# Processing Record 19 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 3 | inta
# Processing Record 21 of Set 3 | jayanca
# Processing Record 22 of Set 3 | sampit
# Processing Record 23 of Set 3 | bathsheba
# Processing Record 24 of Set 3 | puerto rico
# Processing Record 25 of Set 3 | lorengau
# Processing Record 26 of Set 3 | pasni
# Processing Record 27 of Set 3 | zhigansk
# Processing Record 28 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 3 | igarka
# Processing Record 30 of Set 3 | pakaur
# Processing Record 31 of Set 3 | floro
# Processing Record 32 of Set 3 | san quintin
# Processing Record 33 of Set 3 | verkh-usugli
# Processing Record 34 of Set 3 | namibe
# Processing Record 35 of Set 3 | sulangan
# Processing Record 36 of Set 3 | estelle
# Processing Record 37 of Set 3 | luanda
# Processing Record 38 of Set 3 | nikolskoye
# Processing Record 39 of Set 3 | igunga
# Processing Record 40 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 3 | jiujiang
# Processing Record 42 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 3 | boundiali
# Processing Record 44 of Set 3 | tuktoyaktuk
# Processing Record 45 of Set 3 | raudeberg
# Processing Record 46 of Set 3 | tessalit
# Processing Record 47 of Set 3 | lima
# Processing Record 48 of Set 3 | nushki
# Processing Record 49 of Set 3 | tibu
# Processing Record 50 of Set 3 | christchurch
# Processing Record 1 of Set 4 | ilulissat
# Processing Record 2 of Set 4 | nome
# Processing Record 3 of Set 4 | rosetta
# Processing Record 4 of Set 4 | maceio
# Processing Record 5 of Set 4 | pangai
# Processing Record 6 of Set 4 | lagoa
# Processing Record 7 of Set 4 | bourail
# Processing Record 8 of Set 4 | hobyo
# Processing Record 9 of Set 4 | asse
# Processing Record 10 of Set 4 | altay
# Processing Record 11 of Set 4 | bairiki
# Processing Record 12 of Set 4 | ribeira grande
# Processing Record 13 of Set 4 | khandyga
# Processing Record 14 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 4 | calabozo
# Processing Record 16 of Set 4 | saint george
# Processing Record 17 of Set 4 | ahuimanu
# Processing Record 18 of Set 4 | rio gallegos
# Processing Record 19 of Set 4 | thompson
# Processing Record 20 of Set 4 | brumado
# Processing Record 21 of Set 4 | sosnogorsk
# Processing Record 22 of Set 4 | cortez
# Processing Record 23 of Set 4 | borlange
# City not found. Skipping...
# Processing Record 24 of Set 4 | teguise
# Processing Record 25 of Set 4 | arona
# Processing Record 26 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 28 of Set 4 | manakara
# Processing Record 29 of Set 4 | kotturu
# Processing Record 30 of Set 4 | geraldton
# Processing Record 31 of Set 4 | dromolaxia
# Processing Record 32 of Set 4 | margherita
# Processing Record 33 of Set 4 | tygda
# Processing Record 34 of Set 4 | anju
# Processing Record 35 of Set 4 | bueno brandao
# Processing Record 36 of Set 4 | san patricio
# Processing Record 37 of Set 4 | bamnet narong
# Processing Record 38 of Set 4 | ancud
# Processing Record 39 of Set 4 | kifri
# Processing Record 40 of Set 4 | bumba
# Processing Record 41 of Set 4 | whyalla
# Processing Record 42 of Set 4 | shihezi
# Processing Record 43 of Set 4 | fortuna
# Processing Record 44 of Set 4 | nileshwar
# Processing Record 45 of Set 4 | hervey bay
# Processing Record 46 of Set 4 | griffith
# Processing Record 47 of Set 4 | samarai
# Processing Record 48 of Set 4 | bolshaya glushitsa
# Processing Record 49 of Set 4 | saint-georges
# Processing Record 50 of Set 4 | narsaq
# Processing Record 1 of Set 5 | middelburg
# Processing Record 2 of Set 5 | tupik
# Processing Record 3 of Set 5 | phan thiet
# Processing Record 4 of Set 5 | muisne
# Processing Record 5 of Set 5 | sioux lookout
# Processing Record 6 of Set 5 | madison
# Processing Record 7 of Set 5 | veliko gradiste
# Processing Record 8 of Set 5 | fairbanks
# Processing Record 9 of Set 5 | wanning
# Processing Record 10 of Set 5 | poykovskiy
# Processing Record 11 of Set 5 | severo-kurilsk
# Processing Record 12 of Set 5 | victoria
# Processing Record 13 of Set 5 | hilo
# Processing Record 14 of Set 5 | soubre
# Processing Record 15 of Set 5 | los algarrobos
# Processing Record 16 of Set 5 | lasa
# Processing Record 17 of Set 5 | riyadh
# Processing Record 18 of Set 5 | ascension
# Processing Record 19 of Set 5 | carnarvon
# Processing Record 20 of Set 5 | tiksi
# Processing Record 21 of Set 5 | coihaique
# Processing Record 22 of Set 5 | xining
# Processing Record 23 of Set 5 | nanortalik
# Processing Record 24 of Set 5 | klaksvik
# Processing Record 25 of Set 5 | new iberia
# Processing Record 26 of Set 5 | clyde river
# Processing Record 27 of Set 5 | lavrentiya
# Processing Record 28 of Set 5 | comodoro rivadavia
# Processing Record 29 of Set 5 | eyl
# Processing Record 30 of Set 5 | chota
# Processing Record 31 of Set 5 | ostrovnoy
# Processing Record 32 of Set 5 | mar del plata
# Processing Record 33 of Set 5 | gambela
# Processing Record 34 of Set 5 | arman
# Processing Record 35 of Set 5 | torbay
# Processing Record 36 of Set 5 | atikokan
# Processing Record 37 of Set 5 | labuhan
# Processing Record 38 of Set 5 | airai
# Processing Record 39 of Set 5 | xai-xai
# Processing Record 40 of Set 5 | tay ninh
# Processing Record 41 of Set 5 | kutum
# Processing Record 42 of Set 5 | nishihara
# Processing Record 43 of Set 5 | vostok
# Processing Record 44 of Set 5 | sechura
# Processing Record 45 of Set 5 | thomasville
# Processing Record 46 of Set 5 | corralillo
# Processing Record 47 of Set 5 | biak
# Processing Record 48 of Set 5 | roma
# Processing Record 49 of Set 5 | culpeper
# Processing Record 50 of Set 5 | plettenberg bay
# Processing Record 1 of Set 6 | kiunga
# Processing Record 2 of Set 6 | bangassou
# Processing Record 3 of Set 6 | matara
# Processing Record 4 of Set 6 | havelock
# Processing Record 5 of Set 6 | strezhevoy
# Processing Record 6 of Set 6 | vila praia de ancora
# Processing Record 7 of Set 6 | havre-saint-pierre
# Processing Record 8 of Set 6 | thatcham
# Processing Record 9 of Set 6 | kieta
# Processing Record 10 of Set 6 | golden
# Processing Record 11 of Set 6 | manokwari
# Processing Record 12 of Set 6 | nioro
# Processing Record 13 of Set 6 | longyearbyen
# Processing Record 14 of Set 6 | yulara
# Processing Record 15 of Set 6 | grindavik
# Processing Record 16 of Set 6 | brewster
# Processing Record 17 of Set 6 | corinto
# Processing Record 18 of Set 6 | leh
# Processing Record 19 of Set 6 | touros
# Processing Record 20 of Set 6 | north bend
# Processing Record 21 of Set 6 | te anau
# Processing Record 22 of Set 6 | avera
# Processing Record 23 of Set 6 | lingyuan
# Processing Record 24 of Set 6 | goderich
# Processing Record 25 of Set 6 | caravelas
# Processing Record 26 of Set 6 | weligama
# Processing Record 27 of Set 6 | litoral del san juan
# City not found. Skipping...
# Processing Record 28 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 6 | quatre cocos
# Processing Record 30 of Set 6 | wajid
# Processing Record 31 of Set 6 | macas
# Processing Record 32 of Set 6 | troitsko-pechorsk
# Processing Record 33 of Set 6 | skagen
# Processing Record 34 of Set 6 | alofi
# Processing Record 35 of Set 6 | baoning
# Processing Record 36 of Set 6 | birin
# Processing Record 37 of Set 6 | muros
# Processing Record 38 of Set 6 | aitape
# Processing Record 39 of Set 6 | pisco
# Processing Record 40 of Set 6 | bereda
# Processing Record 41 of Set 6 | balakliya
# Processing Record 42 of Set 6 | belen
# Processing Record 43 of Set 6 | khatanga
# Processing Record 44 of Set 6 | puerto leguizamo
# Processing Record 45 of Set 6 | tuatapere
# Processing Record 46 of Set 6 | malatya
# Processing Record 47 of Set 6 | trat
# Processing Record 48 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 6 | clive
# Processing Record 50 of Set 6 | wajir
# Processing Record 1 of Set 7 | bengkulu
# Processing Record 2 of Set 7 | labuan
# Processing Record 3 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 7 | mackay
# Processing Record 5 of Set 7 | erzin
# Processing Record 6 of Set 7 | buenos aires
# Processing Record 7 of Set 7 | agirish
# Processing Record 8 of Set 7 | bodhan
# Processing Record 9 of Set 7 | vardo
# Processing Record 10 of Set 7 | porto novo
# Processing Record 11 of Set 7 | krasnoselkup
# Processing Record 12 of Set 7 | husavik
# Processing Record 13 of Set 7 | buraydah
# Processing Record 14 of Set 7 | velsk
# Processing Record 15 of Set 7 | mogadishu
# Processing Record 16 of Set 7 | zhezkazgan
# Processing Record 17 of Set 7 | kamaishi
# Processing Record 18 of Set 7 | pangnirtung
# Processing Record 19 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 7 | albufeira
# Processing Record 21 of Set 7 | hamilton
# Processing Record 22 of Set 7 | taywarah
# Processing Record 23 of Set 7 | vila velha
# Processing Record 24 of Set 7 | kabugao
# Processing Record 25 of Set 7 | savannah bight
# Processing Record 26 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 7 | arraial do cabo
# Processing Record 28 of Set 7 | machico
# Processing Record 29 of Set 7 | filingue
# Processing Record 30 of Set 7 | anadyr
# Processing Record 31 of Set 7 | colares
# Processing Record 32 of Set 7 | ajuchitlan
# Processing Record 33 of Set 7 | shimoda
# Processing Record 34 of Set 7 | magadan
# Processing Record 35 of Set 7 | manggar
# Processing Record 36 of Set 7 | demirci
# Processing Record 37 of Set 7 | prince rupert
# Processing Record 38 of Set 7 | yeppoon
# Processing Record 39 of Set 7 | viru
# Processing Record 40 of Set 7 | saint anthony
# Processing Record 41 of Set 7 | vryburg
# Processing Record 42 of Set 7 | mago
# Processing Record 43 of Set 7 | yiyang
# Processing Record 44 of Set 7 | ewa beach
# Processing Record 45 of Set 7 | praya
# Processing Record 46 of Set 7 | fort morgan
# Processing Record 47 of Set 7 | hasaki
# Processing Record 48 of Set 7 | ciras
# City not found. Skipping...
# Processing Record 49 of Set 7 | kawalu
# Processing Record 50 of Set 7 | kemi
# Processing Record 1 of Set 8 | port moresby
# Processing Record 2 of Set 8 | batagay
# Processing Record 3 of Set 8 | petropavlovka
# Processing Record 4 of Set 8 | menongue
# Processing Record 5 of Set 8 | umm kaddadah
# Processing Record 6 of Set 8 | fort-shevchenko
# Processing Record 7 of Set 8 | puerto penasco
# Processing Record 8 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 9 of Set 8 | suntar
# Processing Record 10 of Set 8 | danane
# Processing Record 11 of Set 8 | chapais
# Processing Record 12 of Set 8 | monte patria
# Processing Record 13 of Set 8 | tual
# Processing Record 14 of Set 8 | cap malheureux
# Processing Record 15 of Set 8 | san cristobal
# Processing Record 16 of Set 8 | lakes entrance
# Processing Record 17 of Set 8 | qaqortoq
# Processing Record 18 of Set 8 | mount isa
# Processing Record 19 of Set 8 | inongo
# Processing Record 20 of Set 8 | isangel
# Processing Record 21 of Set 8 | matay
# Processing Record 22 of Set 8 | pasighat
# Processing Record 23 of Set 8 | katsuura
# Processing Record 24 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 8 | madras
# Processing Record 26 of Set 8 | makakilo city
# Processing Record 27 of Set 8 | tilichiki
# Processing Record 28 of Set 8 | itoman
# Processing Record 29 of Set 8 | panzhihua
# Processing Record 30 of Set 8 | natal
# Processing Record 31 of Set 8 | kavaratti
# Processing Record 32 of Set 8 | emerald
# Processing Record 33 of Set 8 | abeche
# Processing Record 34 of Set 8 | mandalgovi
# Processing Record 35 of Set 8 | burica
# City not found. Skipping...
# Processing Record 36 of Set 8 | chaiyaphum
# Processing Record 37 of Set 8 | inhambane
# Processing Record 38 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 39 of Set 8 | parit buntar
# Processing Record 40 of Set 8 | plouzane
# Processing Record 41 of Set 8 | selaphum
# Processing Record 42 of Set 8 | olafsvik
# Processing Record 43 of Set 8 | nkhotakota
# Processing Record 44 of Set 8 | charters towers
# Processing Record 45 of Set 8 | vanimo
# Processing Record 46 of Set 8 | keti bandar
# Processing Record 47 of Set 8 | la plata
# Processing Record 48 of Set 8 | safranbolu
# Processing Record 49 of Set 8 | omboue
# Processing Record 50 of Set 8 | sao filipe
# Processing Record 1 of Set 9 | villaviciosa
# Processing Record 2 of Set 9 | fort nelson
# Processing Record 3 of Set 9 | hailar
# Processing Record 4 of Set 9 | nara
# Processing Record 5 of Set 9 | sorong
# Processing Record 6 of Set 9 | kendrapara
# Processing Record 7 of Set 9 | talnakh
# Processing Record 8 of Set 9 | port blair
# Processing Record 9 of Set 9 | bend
# Processing Record 10 of Set 9 | newcastle
# Processing Record 11 of Set 9 | sayyan
# Processing Record 12 of Set 9 | garissa
# Processing Record 13 of Set 9 | cap-aux-meules
# Processing Record 14 of Set 9 | luderitz
# Processing Record 15 of Set 9 | rutana
# Processing Record 16 of Set 9 | zeya
# Processing Record 17 of Set 9 | tyup
# Processing Record 18 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 19 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 20 of Set 9 | fomboni
# Processing Record 21 of Set 9 | vanderhoof
# Processing Record 22 of Set 9 | challans
# Processing Record 23 of Set 9 | kurmanayevka
# Processing Record 24 of Set 9 | ipanema
# Processing Record 25 of Set 9 | kudahuvadhoo
# Processing Record 26 of Set 9 | ixcaquixtla
# City not found. Skipping...
# Processing Record 27 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 9 | kampong thum
# Processing Record 29 of Set 9 | bonthe
# Processing Record 30 of Set 9 | richards bay
# Processing Record 31 of Set 9 | noumea
# Processing Record 32 of Set 9 | durazno
# Processing Record 33 of Set 9 | rio grande
# Processing Record 34 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 35 of Set 9 | orange
# Processing Record 36 of Set 9 | the valley
# Processing Record 37 of Set 9 | kismayo
# Processing Record 38 of Set 9 | gopichettipalaiyam
# City not found. Skipping...
# Processing Record 39 of Set 9 | faranah
# Processing Record 40 of Set 9 | los llanos de aridane
# Processing Record 41 of Set 9 | tutoia
# Processing Record 42 of Set 9 | zhuanghe
# Processing Record 43 of Set 9 | taft
# Processing Record 44 of Set 9 | poum
# Processing Record 45 of Set 9 | srednekolymsk
# Processing Record 46 of Set 9 | kuliyapitiya
# Processing Record 47 of Set 9 | pevek
# Processing Record 48 of Set 9 | sao felix do xingu
# Processing Record 49 of Set 9 | boa vista
# Processing Record 50 of Set 9 | mabamba
# Processing Record 1 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 10 | faya
# Processing Record 3 of Set 10 | kupang
# Processing Record 4 of Set 10 | aden
# Processing Record 5 of Set 10 | campo maior
# Processing Record 6 of Set 10 | zaragoza
# Processing Record 7 of Set 10 | port hawkesbury
# Processing Record 8 of Set 10 | kula
# Processing Record 9 of Set 10 | iqaluit
# Processing Record 10 of Set 10 | orchard homes
# Processing Record 11 of Set 10 | huron
# Processing Record 12 of Set 10 | miles city
# Processing Record 13 of Set 10 | ulagan
# Processing Record 14 of Set 10 | magdagachi
# Processing Record 15 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 16 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 17 of Set 10 | walker
# Processing Record 18 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 19 of Set 10 | pacific grove
# Processing Record 20 of Set 10 | port augusta
# Processing Record 21 of Set 10 | terrace
# Processing Record 22 of Set 10 | imeni poliny osipenko
# Processing Record 23 of Set 10 | loudi
# Processing Record 24 of Set 10 | namtsy
# Processing Record 25 of Set 10 | dipkarpaz
# City not found. Skipping...
# Processing Record 26 of Set 10 | netrakona
# Processing Record 27 of Set 10 | wollongong
# Processing Record 28 of Set 10 | khandagayty
# Processing Record 29 of Set 10 | areosa
# Processing Record 30 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 10 | kirillov
# Processing Record 32 of Set 10 | yelizovo
# Processing Record 33 of Set 10 | snezhnogorsk
# Processing Record 34 of Set 10 | puerto carreno
# Processing Record 35 of Set 10 | maryville
# Processing Record 36 of Set 10 | aksarka
# Processing Record 37 of Set 10 | tambopata
# Processing Record 38 of Set 10 | pozoblanco
# Processing Record 39 of Set 10 | sotouboua
# Processing Record 40 of Set 10 | kununurra
# Processing Record 41 of Set 10 | cukai
# Processing Record 42 of Set 10 | dois corregos
# Processing Record 43 of Set 10 | itaqui
# Processing Record 44 of Set 10 | paka
# Processing Record 45 of Set 10 | ayan
# Processing Record 46 of Set 10 | wanaka
# Processing Record 47 of Set 10 | birjand
# Processing Record 48 of Set 10 | upington
# Processing Record 49 of Set 10 | warora
# Processing Record 50 of Set 10 | kailua
# Processing Record 1 of Set 11 | korla
# Processing Record 2 of Set 11 | arawa
# Processing Record 3 of Set 11 | castenaso
# Processing Record 4 of Set 11 | sibolga
# Processing Record 5 of Set 11 | timra
# Processing Record 6 of Set 11 | sistranda
# Processing Record 7 of Set 11 | carlyle
# Processing Record 8 of Set 11 | progreso
# Processing Record 9 of Set 11 | latehar
# Processing Record 10 of Set 11 | marzuq
# Processing Record 11 of Set 11 | chase
# Processing Record 12 of Set 11 | flin flon
# Processing Record 13 of Set 11 | khonsa
# Processing Record 14 of Set 11 | byron bay
# Processing Record 15 of Set 11 | rancho palos verdes
# Processing Record 16 of Set 11 | bukachacha
# Processing Record 17 of Set 11 | maniitsoq
# Processing Record 18 of Set 11 | meadow lake
# Processing Record 19 of Set 11 | camana
# Processing Record 20 of Set 11 | provo
# Processing Record 21 of Set 11 | tshikapa
# Processing Record 22 of Set 11 | dubbo
# Processing Record 23 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 24 of Set 11 | bagrami
# Processing Record 25 of Set 11 | nam dinh
# Processing Record 26 of Set 11 | diego de almagro
# Processing Record 27 of Set 11 | rio bonito
# Processing Record 28 of Set 11 | lugovoy
# Processing Record 29 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 30 of Set 11 | pinar del rio
# Processing Record 31 of Set 11 | luwingu
# Processing Record 32 of Set 11 | margate
# Processing Record 33 of Set 11 | tagusao
# Processing Record 34 of Set 11 | witu
# Processing Record 35 of Set 11 | teguldet
# Processing Record 36 of Set 11 | mangrol
# Processing Record 37 of Set 11 | digboi
# Processing Record 38 of Set 11 | miyako
# Processing Record 39 of Set 11 | gualaquiza
# Processing Record 40 of Set 11 | izhma
# Processing Record 41 of Set 11 | ardistan
# City not found. Skipping...
# Processing Record 42 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 43 of Set 11 | necochea
# Processing Record 44 of Set 11 | mareeba
# Processing Record 45 of Set 11 | uk
# City not found. Skipping...
# Processing Record 46 of Set 11 | chifeng
# Processing Record 47 of Set 11 | winnemucca
# Processing Record 48 of Set 11 | opuwo
# Processing Record 49 of Set 11 | karaton
# Processing Record 50 of Set 11 | gornopravdinsk
# Processing Record 1 of Set 12 | neiafu
# Processing Record 2 of Set 12 | camacupa
# Processing Record 3 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 4 of Set 12 | algiers
# Processing Record 5 of Set 12 | maputo
# Processing Record 6 of Set 12 | port lincoln
# Processing Record 7 of Set 12 | ubinskoye
# Processing Record 8 of Set 12 | derzhavinsk
# Processing Record 9 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 10 of Set 12 | moses lake
# Processing Record 11 of Set 12 | buriti bravo
# Processing Record 12 of Set 12 | yueyang
# Processing Record 13 of Set 12 | vila franca do campo
# Processing Record 14 of Set 12 | juifang
# City not found. Skipping...
# Processing Record 15 of Set 12 | flinders
# Processing Record 16 of Set 12 | ubaira
# Processing Record 17 of Set 12 | beringovskiy
# Processing Record 18 of Set 12 | shirokiy
# Processing Record 19 of Set 12 | vao
# Processing Record 20 of Set 12 | tuy hoa
# Processing Record 21 of Set 12 | kavieng
# Processing Record 22 of Set 12 | koslan
# Processing Record 23 of Set 12 | half moon bay
# Processing Record 24 of Set 12 | sitka
# Processing Record 25 of Set 12 | ocean city
# Processing Record 26 of Set 12 | acuna
# City not found. Skipping...
# Processing Record 27 of Set 12 | oranjemund
# Processing Record 28 of Set 12 | gushikawa
# Processing Record 29 of Set 12 | marietta
# Processing Record 30 of Set 12 | huanuco
# Processing Record 31 of Set 12 | tete
# Processing Record 32 of Set 12 | arroio dos ratos
# Processing Record 33 of Set 12 | maltahohe
# Processing Record 34 of Set 12 | lazarev
# Processing Record 35 of Set 12 | north platte
# Processing Record 36 of Set 12 | tanda
# Processing Record 37 of Set 12 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 38 of Set 12 | dibulla
# Processing Record 39 of Set 12 | acari
# Processing Record 40 of Set 12 | ust-ishim
# Processing Record 41 of Set 12 | danville
# Processing Record 42 of Set 12 | aksu
# Processing Record 43 of Set 12 | muborak
# Processing Record 44 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 12 | sterlibashevo
# Processing Record 46 of Set 12 | tefe
# Processing Record 47 of Set 12 | ambanja
# Processing Record 48 of Set 12 | sirnak
# Processing Record 49 of Set 12 | tarata
# Processing Record 50 of Set 12 | lake havasu city
# Processing Record 1 of Set 13 | lata
# Processing Record 2 of Set 13 | saundatti yellamma
# City not found. Skipping...
# Processing Record 3 of Set 13 | pokosnoye
# Processing Record 4 of Set 13 | nampula
# Processing Record 5 of Set 13 | marawi
# Processing Record 6 of Set 13 | rorvik
# Processing Record 7 of Set 13 | hovd
# Processing Record 8 of Set 13 | valparaiso
# Processing Record 9 of Set 13 | moree
# Processing Record 10 of Set 13 | wakkanai
# Processing Record 11 of Set 13 | saint leonard
# Processing Record 12 of Set 13 | port-gentil
# Processing Record 13 of Set 13 | sierpc
# Processing Record 14 of Set 13 | kerema
# Processing Record 15 of Set 13 | san vicente
# Processing Record 16 of Set 13 | shingu
# Processing Record 17 of Set 13 | timmins
# Processing Record 18 of Set 13 | marrakesh
# Processing Record 19 of Set 13 | skibbereen
# Processing Record 20 of Set 13 | venkatagiri
# Processing Record 21 of Set 13 | shinpokh
# Processing Record 22 of Set 13 | rawson
# Processing Record 23 of Set 13 | manadhoo
# Processing Record 24 of Set 13 | kizukuri
# Processing Record 25 of Set 13 | dudinka
# Processing Record 26 of Set 13 | ano mera
# Processing Record 27 of Set 13 | kropotkin
# Processing Record 28 of Set 13 | lagos
# Processing Record 29 of Set 13 | leningradskiy
# Processing Record 30 of Set 13 | sao jose da coroa grande
# Processing Record 31 of Set 13 | taoudenni
# Processing Record 32 of Set 13 | codajas
# Processing Record 33 of Set 13 | bela vista do paraiso
# Processing Record 34 of Set 13 | hua hin
# Processing Record 35 of Set 13 | mersing
# Processing Record 36 of Set 13 | bandarbeyla
# Processing Record 37 of Set 13 | sabang
# Processing Record 38 of Set 13 | tanete
# Processing Record 39 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 13 | glarus
# Processing Record 41 of Set 13 | chernyy yar
# Processing Record 42 of Set 13 | lodeynoye pole
# Processing Record 43 of Set 13 | boyolangu
# Processing Record 44 of Set 13 | staryy nadym
# Processing Record 45 of Set 13 | pahrump
# Processing Record 46 of Set 13 | qui nhon
# Processing Record 47 of Set 13 | huarmey
# Processing Record 48 of Set 13 | amos
# Processing Record 49 of Set 13 | san luis
# Processing Record 50 of Set 13 | juneau
# Processing Record 1 of Set 14 | barao de melgaco
# Processing Record 2 of Set 14 | bogatyye saby
# Processing Record 3 of Set 14 | pueblo bello
# Processing Record 4 of Set 14 | shupiyan
# Processing Record 5 of Set 14 | duzce
# Processing Record 6 of Set 14 | havoysund
# Processing Record 7 of Set 14 | guabito
# Processing Record 8 of Set 14 | ocara
# Processing Record 9 of Set 14 | abnub
# Processing Record 10 of Set 14 | lunglei
# Processing Record 11 of Set 14 | ende
# Processing Record 12 of Set 14 | salym
# Processing Record 13 of Set 14 | jatiroto
# Processing Record 14 of Set 14 | balotra
# Processing Record 15 of Set 14 | araouane
# Processing Record 16 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 14 | oil city
# Processing Record 18 of Set 14 | am timan
# Processing Record 19 of Set 14 | honiara
# Processing Record 20 of Set 14 | chai badan
# Processing Record 21 of Set 14 | zhaoqing
# Processing Record 22 of Set 14 | bela
# Processing Record 23 of Set 14 | meridian
# Processing Record 24 of Set 14 | santa vitoria do palmar
# Processing Record 25 of Set 14 | kaltenkirchen
# Processing Record 26 of Set 14 | dembi dolo
# Processing Record 27 of Set 14 | sabya
# Processing Record 28 of Set 14 | bahir dar
# Processing Record 29 of Set 14 | awjilah
# Processing Record 30 of Set 14 | castres
# Processing Record 31 of Set 14 | siemiatycze
# Processing Record 32 of Set 14 | plaster rock
# Processing Record 33 of Set 14 | wolfratshausen
# Processing Record 34 of Set 14 | ahipara
# Processing Record 35 of Set 14 | crab hill
# City not found. Skipping...
# Processing Record 36 of Set 14 | atambua
# Processing Record 37 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 38 of Set 14 | kargasok
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Chokurdakh  70.6333  147.9167     38.50        73           1       10.00
# 1  Georgetown   5.4112  100.3354     83.89        86          20        0.00
# 2  Kaitangata -46.2817  169.8464     49.93        59         100        3.83
# 3    Tasiilaq  65.6145  -37.6368     39.60        86          55        5.64
# 4      Kodiak  57.7900 -152.4072     53.11        82          90        5.75
#
#   Country Current Description
# 0      RU           clear sky
# 1      MY          few clouds
# 2      NZ       moderate rain
# 3      GL       broken clouds
# 4      US                haze

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity","Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0        Chokurdakh      RU  70.6333  147.9167     38.50        73
# 1        Georgetown      MY   5.4112  100.3354     83.89        86
# 2        Kaitangata      NZ -46.2817  169.8464     49.93        59
# 3          Tasiilaq      GL  65.6145  -37.6368     39.60        86
# 4            Kodiak      US  57.7900 -152.4072     53.11        82
# ..              ...     ...      ...       ...       ...       ...
# 669    Plaster Rock      CA  46.9065  -67.3900     67.06        93
# 670  Wolfratshausen      DE  47.9129   11.4217     69.66        90
# 671         Ahipara      NZ -35.1667  173.1667     57.27        92
# 672         Atambua      ID  -9.1061  124.8925     66.83        73
# 673        Kargasok      RU  59.0556   80.8572     63.32        83
#
#      Cloudiness  Wind Speed Current Description
# 0             1       10.00           clear sky
# 1            20        0.00          few clouds
# 2           100        3.83       moderate rain
# 3            55        5.64       broken clouds
# 4            90        5.75                haze
# ..          ...         ...                 ...
# 669         100       10.31          light rain
# 670          75        0.85       broken clouds
# 671          15        9.86          few clouds
# 672          75        3.78       broken clouds
# 673          92        4.74     overcast clouds
#
# [674 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
